# %% [markdown]
# <a href="https://colab.research.google.com/github/hectoresc/MineriaDeDatos/blob/main/Ej_Python_2034174.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ej_Python_2034174

# %%
#Ejercicio 1
#Realiza una variable con tu matricula y realiza una secuencia de imprimir con tu nombre y tu matricula concatenados

matricula="2034174"
print(matricula,"Andrea Sarahi Gómez Avila")
print(" ")
      
#Ejercicio 2
#Pidiendo el input del usuario pide dos números y crea una pequeña calculadora con los operadores básicos de suma, resta, multiplicación, división, y exponente.

num1 = int(input("Introduce un número:"))
num2 = int(input("Introduce otro número:"))
print(" ")

suma = num1 + num2
resta= num1 - num2
mult = num1 * num2
div = num1 / num2
exp = pow(num1,num2)

print(num1,"+",num2,"=",suma)
print(num1,"-",num2,"=",resta)
print(num1,"*",num2,"=",mult)
print(num1,"/",num2,"=",div)
print(num1,"^",num2,"=",exp)
print(" ")

#Ejercicio 3
#Con loop while o for, realiza una lista de 10 numeros multiplos de 3, y después realiza una función de loop que sume todos los números dentro del arreglo.

num = int(input("Introduce un número"))

divisor=3
contador=1
suma=0

for contador in range (1,n+1):
    multiplo=1
    residuo=contador%divisor
    if(residuo==0):
        multiplo=contador
        if(multiplo==contador):
            print(contador)
            suma=suma+contador
print("La suma de la lista anterios es",suma)
print(" ")

#Ejercicio 4
#Con una función de if else, revisar si un número es par o es impar.
#Con una función de if else, revisar si un número es primo o no.

num = int(input("Introduce un número:"))

if num % 2 == 0:
    print(num,"es un número par")
else:
    print(num,"es un número impar")

for n in range(2,num):
    if num % n == 0:
        print(num,"es un número primo")
else:
    print(num,"no es un número primo")

#Ejercicio 5
#Utilizando diferentes clases en python, crea una calculadora con los operadores básicos de suma, resta, multiplicación, división, y exponente.

z=6+9
print(z)

z=6*9
print(z)

z=6-9
print(z)

z=9/6
print(z)

z=9//6
print(z)
print(" ")

#Tuplas

import numpy as np

flt = float(np.pi)
type(flt)

ing = int(100)
type(int)

bol = True
type(bol)

com = .876j
type(com) 


tupla = (1,2,3,4,5)
tupla[0]
tupla[len(tupla)-1]

tp2 = ("a", "b", "c")

tupla = tupla + tp2
tupla


if 20 in tupla:
  print("Sí está en tupla")
else:
  print("No está en tupla")

#Listas

import random as r
l=list(r.sample(range(1,100),40))
print(l)
print(" ")

lp=[par for par in l if par%2==0]
print(lp)
print(" ")

lmp=[impar for impar in l if impar%2!=0]
print(lmp)
print(" ")

longpar=len(lp)
print(longpar)
print(" ")

longimpar=len(lmp)
print(longimpar)
print(" ")

lp=sorted(lp,reverse=True)
print(lp)
print(" ")

lmp=sorted(lmp)
print(lmp)
print(" ")

for i in range(len(l)):
    try:
        print(i,"-->",l[i])
    except:
        print("Error")
print(" ")

for i in range(5):
    try:
        print(i,"-->",l[i])
    except:
        print("Error")
len(l)
print(" ")

print(l[9])
print(" ")

l[8]="Andrea"
print(l)
print(" ")


#Diccionarios
diccionario={'nombre1':'Andrea','edad1':21,'nombre2':'Ximena','edad2':19,'nombre3':'Gabriela','edad3':14,'nombre4':'Melissa','edad4':23,'nombre5':'Viky','edad5':43,'nombre6':'Hugo','edad6':44}

l=[diccionario['edad1'],diccionario['edad2'],diccionario['edad3'],diccionario['edad4'],diccionario['edad5'],diccionario['edad6']]
print(l)
print(" ")

l=sorted(l)
print(l)
print(" ")

diccionario['nombre7']="Daniel"
diccionario['edad']=25
diccionario['nombre8']="Alejando"
diccionario['edad']=23
print(" ")

#Sets 
st = set([])

import random as r

for i in range(1,101):
  st.add(r.randint(1,25))

len(st)


listaa = []

for i in range(1,6):
  listaa.append(r.randint(1,10))

listaa

for i in listaa:
  print(i in st)
